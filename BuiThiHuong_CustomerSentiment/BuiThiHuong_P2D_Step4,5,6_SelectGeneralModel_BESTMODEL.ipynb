# %% [markdown]
# ## Import libraries

# %%
# !pip install pyvi
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 8.5 MB 5.3 MB/s
# ...
#      |████████████████████████████████| 965 kB 61.4 MB/s
# ...

# %%
# !pip install underthesea
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 7.6 MB 4.4 MB/s
# ...
#      |████████████████████████████████| 581 kB 54.2 MB/s
# ...
#      |████████████████████████████████| 235 kB 68.7 MB/s
# ...

# %%
# !pip install demoji
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 42 kB 702 kB/s
# ...

# %%
# !pip install lazypredict
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 25.9 MB 1.2 MB/s
# ...
#      |████████████████████████████████| 10.1 MB 38.9 MB/s
# ...
#      |████████████████████████████████| 127.6 MB 1.2 MB/s
# ...
#      |████████████████████████████████| 1.2 MB 47.3 MB/s
# ...
#      |████████████████████████████████| 248 kB 73.8 MB/s
# ...
#      |████████████████████████████████| 302 kB 71.8 MB/s
# ...
#      |████████████████████████████████| 6.8 MB 30.0 MB/s
# ...
#      |████████████████████████████████| 72 kB 881 kB/s
# ...
#      |████████████████████████████████| 269 kB 58.5 MB/s
# ...
#      |████████████████████████████████| 14.5 MB 38.6 MB/s
# ...
#   Created wheel for PyYAML: filename=PyYAML-5.3.1-cp37-cp37m-linux_x86_64.whl size=44636 sha256=b1630802264a721e643ec97e506ca50a0ea7d93c73f2424e061e8bd855c562fc
#   Stored in directory: /root/.cache/pip/wheels/5e/03/1e/e1e954795d6f35dfc7b637fe2277bff021303bd9570ecea653
# Successfully built PyYAML
# ...

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import drive
drive.mount("/content/gdrive", force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
# %cd '/content/gdrive/My Drive/LDS0_K276_BuiThiHuong/Topic2'
# Out:
# /content/gdrive/My Drive/LDS0_K276_BuiThiHuong/Topic2

# %%
import time
import pandas as pd
import numpy as np
from sklearn.naive_bayes import MultinomialNB
from lazypredict.Supervised import LazyClassifier
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report, confusion_matrix 
from sklearn.model_selection import train_test_split  
from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics
import matplotlib.pyplot as plt
# thu vien Tokenizer Viet
from pyvi import ViTokenizer, ViPosTagger
from wordcloud import WordCloud

import glob as gl
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# saving model libraries
from sklearn.pipeline import Pipeline
import pickle

# import import_ipynb
# from lib_NLP import *

# %%
pip install ipynb
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# %cd '/content/gdrive/My Drive/LDS0_K276_BuiThiHuong/Topic2/lib'
# %run function_lib.ipynb     #this is were my function was stored
# Out:
# /content/gdrive/My Drive/LDS0_K276_BuiThiHuong/Topic2/lib

# %%
# %cd '/content/gdrive/My Drive/LDS0_K276_BuiThiHuong/Topic2/'
# Out:
# /content/gdrive/My Drive/LDS0_K276_BuiThiHuong/Topic2

# %% [markdown]
# # Step 4&5: MODELING & EVALUATION/ ANALYZE AND REPORT

# %% [markdown]
# ### Load data

# %% [markdown]
# Load undersampling data

# %%
# list_files = gl.glob("outputs/X_train_us_self_?.csv")
# list_files
# Out:
# ['outputs/X_train_us_1.csv', 'outputs/X_train_us_2.csv']

# %%
# lst_data = []
# for file in list_files:
#     df_temp = pd.read_csv(file)
#     lst_data.append(df_temp)

# %%
X_train_us = pd.read_csv('outputs/X_train_us_self.csv')

# %%
y_train_us = pd.read_csv('outputs/y_train_us_self.csv')

# %%
X_test = pd.read_csv('outputs/X_test_self.csv')

# %%
y_test = pd.read_csv('outputs/y_test_self.csv')

# %%
X_train_us = X_train_us.iloc[:,1:]

# %%
y_train_us = y_train_us.iloc[:,1:]

# %%
X_test = X_test.iloc[:,1:]

# %%
y_test = y_test.iloc[:,1:]

# %% [markdown]
# Load oversampling data

# %%
# list_files = gl.glob("outputs/X_train_os_?.csv")
# list_files

# %%
# lst_data = []
# for file in list_files:
#     df_temp = pd.read_csv(file)
#     lst_data.append(df_temp)

# %%
# X_train_os = pd.concat(lst_data)

# %%
X_train_os = pd.read_csv('outputs/X_train_os_self.csv')

# %%
y_train_os = pd.read_csv('outputs/y_train_os_self.csv')

# %%
X_train_os = X_train_os.iloc[:,1:]

# %%
y_train_os = y_train_os.iloc[:,1:]

# %% [markdown]
# ## LazyPredict

# %% [markdown]
# ### Build model

# %%
clf_us = LazyClassifier(verbose=0, ignore_warnings=True, custom_metric=None)
clf_os = LazyClassifier(verbose=0, ignore_warnings=True, custom_metric=None)

# %%
models_us, predictions_us = clf_us.fit(X_train_us, X_test, y_train_us, y_test)
# Out:
# 100%|██████████| 29/29 [57:46<00:00, 119.55s/it]

# %%
# models_us = pd.read_csv('outputs/LazyClassifier_models_us.csv')

# %%
models_us
# Out:
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# LGBMClassifier                     0.84               0.83     0.83      0.85
# BernoulliNB                        0.83               0.83     0.83      0.84
# XGBClassifier                      0.83               0.82     0.82      0.84
# ExtraTreesClassifier               0.86               0.82     0.82      0.87
# NearestCentroid                    0.81               0.82     0.82      0.82
# RandomForestClassifier             0.86               0.81     0.81      0.87
# SVC                                0.79               0.81     0.81      0.80
# NuSVC                              0.79               0.80     0.80      0.81
# CalibratedClassifierCV             0.81               0.80     0.80      0.82
# RidgeClassifierCV                  0.79               0.79     0.79      0.81
# RidgeClassifier                    0.79               0.79     0.79      0.81
# ...

# %%
# # save
models_us.to_csv('outputs/LazyClassifier_models_us_self.csv')

# %%
models_os, predictions_os = clf_os.fit(X_train_os, X_test, y_train_os, y_test)
# Out:
#  38%|███▊      | 11/29 [58:58<2:40:22, 534.56s/it]

# %%
models_os

# %%
# # save
models_os.to_csv('outputs/LazyClassifier_models_os_self.csv')
# pickle.dump(clf_mb_us, open('outputs/MultinomialNB_us_model.sav', 'wb'))

# %% [markdown]
# ### Conclusion:
# * According to ROC AUC, F1-score, Accuracy of general models of LazyClassifier, the Naive Bayes models and Tree models are the suiltable.
# * Next steps: Build and evaluate each models: MultinomialMB, BernoulliNB, LGBMClassifier, ExtraTreesClassifier, RandomForestClassifier and another model: RNN LSTM.
