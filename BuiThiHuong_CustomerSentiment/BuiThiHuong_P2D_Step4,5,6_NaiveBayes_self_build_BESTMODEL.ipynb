# %% [markdown]
# ## Import libraries

# %%
# !pip install pyvi
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 8.5 MB 15.3 MB/s
# ...
#      |████████████████████████████████| 965 kB 60.1 MB/s
# ...

# %%
# !pip install underthesea
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 7.6 MB 5.4 MB/s
# ...
#      |████████████████████████████████| 235 kB 82.9 MB/s
# ...
#      |████████████████████████████████| 581 kB 45.8 MB/s
# ...

# %%
# !pip install demoji
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 42 kB 1.5 MB/s
# ...

# %%
# !pip install emoji
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 175 kB 13.7 MB/s
# ...
#   Created wheel for emoji: filename=emoji-1.7.0-py3-none-any.whl size=171046 sha256=8e7cb7aa622933e442721af9c308e06046ae0fed781a0d8618b20313b85f37da
#   Stored in directory: /root/.cache/pip/wheels/8a/4e/b6/57b01db010d17ef6ea9b40300af725ef3e210cb1acfb7ac8b6
# Successfully built emoji
# ...

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import drive
drive.mount("/content/gdrive", force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
# %cd '/content/gdrive/My Drive/LDS0_K276_BuiThiHuong/Topic2'
# Out:
# /content/gdrive/My Drive/LDS0_K276_BuiThiHuong/Topic2

# %%
import time
import pandas as pd
import numpy as np
from sklearn.naive_bayes import MultinomialNB, BernoulliNB
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report, confusion_matrix 
from sklearn.model_selection import train_test_split  
from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics
import matplotlib.pyplot as plt
# thu vien Tokenizer Viet
from pyvi import ViTokenizer, ViPosTagger
from wordcloud import WordCloud

import glob as gl
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

import emoji
import re

# saving model libraries
from sklearn.pipeline import Pipeline
import pickle

# import import_ipynb
# from lib_NLP import *

# %%
pip install ipynb
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# %cd '/content/gdrive/My Drive/LDS0_K276_BuiThiHuong/Topic2/lib'
# %run function_lib.ipynb     #this is were my function was stored
# Out:
# /content/gdrive/My Drive/LDS0_K276_BuiThiHuong/Topic2/lib

# %%
# %cd '/content/gdrive/My Drive/LDS0_K276_BuiThiHuong/Topic2/'
# Out:
# /content/gdrive/My Drive/LDS0_K276_BuiThiHuong/Topic2

# %% [markdown]
# # Step 4&5: MODELING & EVALUATION/ ANALYZE AND REPORT

# %% [markdown]
# ### Load data

# %% [markdown]
# Load undersampling data

# %%
# list_files = gl.glob("outputs/X_train_us_self_?.csv")
# list_files
# Out:
# ['outputs/X_train_us_1.csv', 'outputs/X_train_us_2.csv']

# %%
# lst_data = []
# for file in list_files:
#     df_temp = pd.read_csv(file)
#     lst_data.append(df_temp)

# %%
X_train_us = pd.read_csv('outputs/X_train_us_self.csv')

# %%
y_train_us = pd.read_csv('outputs/y_train_us_self.csv')

# %%
X_test = pd.read_csv('outputs/X_test_self.csv')

# %%
y_test = pd.read_csv('outputs/y_test_self.csv')

# %%
X_train_us = X_train_us.iloc[:,1:]

# %%
y_train_us = y_train_us.iloc[:,1:]

# %%
X_test = X_test.iloc[:,1:]

# %%
y_test = y_test.iloc[:,1:]

# %% [markdown]
# Load oversampling data

# %%
# list_files = gl.glob("outputs/X_train_os_?.csv")
# list_files
# Out:
# ['outputs/X_train_os_1.csv',
#  'outputs/X_train_os_2.csv',
#  'outputs/X_train_os_3.csv',
#  'outputs/X_train_os_4.csv']

# %%
# lst_data = []
# for file in list_files:
#     df_temp = pd.read_csv(file)
#     lst_data.append(df_temp)

# %%
# X_train_os = pd.concat(lst_data)

# %%
X_train_os = pd.read_csv('outputs/X_train_os_self.csv')

# %%
y_train_os = pd.read_csv('outputs/y_train_os_self.csv')

# %%
X_train_os = X_train_os.iloc[:,1:]

# %%
y_train_os = y_train_os.iloc[:,1:]

# %% [markdown]
# ## MultinomialNB

# %% [markdown]
# ### Build model

# %%
clf_mb_us = MultinomialNB()
clf_mb_os = MultinomialNB()

# %%
clf_mb_us.fit(X_train_us, y_train_us)
clf_mb_os.fit(X_train_os, y_train_os)
# Out:
# MultinomialNB()

# %%
# save model
pickle.dump(clf_mb_us, open('outputs/MultinomialNB_us_self_model.sav', 'wb'))
pickle.dump(clf_mb_os, open('outputs/MultinomialNB_os_self_model.sav', 'wb'))

# %% [markdown]
# ### Model Evaluation

# %%
y_testhat_us = clf_mb_us.predict(X_test)
y_testhat_os = clf_mb_os.predict(X_test)

# %%
# Evaluation - Undersampling
print(confusion_matrix(y_test, y_testhat_us))
# Out:
# [[8418  986]
#  [ 524 1908]]

# %%
print(classification_report(y_test, y_testhat_us))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.90      0.92      9404
#            1       0.66      0.78      0.72      2432
#
#     accuracy                           0.87     11836
#    macro avg       0.80      0.84      0.82     11836
# weighted avg       0.88      0.87      0.88     11836

# %%
# Evaluation - Oversampling
print(confusion_matrix(y_test, y_testhat_os))
# Out:
# [[8448  956]
#  [ 597 1835]]

# %%
print(classification_report(y_test, y_testhat_os))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.90      0.92      9404
#            1       0.66      0.75      0.70      2432
#
#     accuracy                           0.87     11836
#    macro avg       0.80      0.83      0.81     11836
# weighted avg       0.88      0.87      0.87     11836

# %% [markdown]
# ### Prediction

# %%
# # load model
# clf_mb_us = pickle.load(open('outputs/MultinomialNB_us_model.sav', 'rb'))

# %%
df_clean_cv = pd.read_csv('outputs/df_clean_self_cv.csv')

# %%
df_clean_cv = df_clean_cv.set_index('index')

# %%
X = df_clean_cv.iloc[:,7:]

# %%
y_hat = clf_mb_us.predict(X)

# %%
y_hat[:5]
# Out:
# array([0, 0, 0, 0, 0])

# %%
df_clean_predict = df_clean_cv.iloc[:,2:7].reset_index()
df_clean_predict['predict'] = y_hat
df_clean_predict.head()
# Out:
#    index                                      restaurant  \
# 0      0                         Good Morning Restaurant
# 1      1                              Hạt Dẻ Trùng Khánh
# 2      2  Bột - Healthy & Weight Loss Food - Shop Online
# 3      3                    Bánh Giò Chợ Nguyễn Công Trứ
# 4      4                          Quán Quảng - Bún Quảng
#
#                                          review_text  review_score  \
# 0  Pizza phong cách Ý. Ngán hải sản nên cả nhà gh...           8.2
# 1  - Vị trí: chỉ là 1 chiếc xe nho nhỏ nằm ở khu ...           8.0
# 2  Nay lang thang trên BM thấy đang khuyến mãi xo...           8.2
# 3  Quán nằm trong chợ Nguyễn Công Trứ, cũng dễ tì...           8.2
# 4  Ngãi heo với heo thiệttttt 🐷🐷🐷\n🤤🤤 bún nem chả...           9.0
#
#                                    review_text_clean  review_score_new  \
# 0              phong_cách ngán rẻ trình_bày đẹp đúng                 0
# 1  nho_nhỏ thôi đông chất_lượng thích sạch_sẽ cảm...                 0
# ...

# %%
pd.crosstab(df_clean_predict['review_score_new'],df_clean_predict['predict'])
# Out:
# predict               0     1
# review_score_new
# 0                 28099  3196
# 1                  1656  6501

# %%
# save
df_clean_predict.to_excel('outputs/df_BernoulliNB_us_self_predict.xls', sheet_name='Sheet1', encoding='utf-8')

# %%
1-1656/(1656+6501)
# Out:
# 0.7969841853622656

# %% [markdown]
# ## BernoulliNB

# %% [markdown]
# ### Build model

# %%
clf_bb_us = BernoulliNB()
clf_bb_os = BernoulliNB()

# %%
clf_bb_us.fit(X_train_us, y_train_us)
clf_bb_os.fit(X_train_os, y_train_os)
# Out:
# BernoulliNB()

# %%
# save model
pickle.dump(clf_bb_us, open('outputs/BernoulliNB_us_self_model.sav', 'wb'))
pickle.dump(clf_bb_os, open('outputs/BernoulliNB_os_self_model.sav', 'wb'))

# %% [markdown]
# ### Model Evaluation

# %%
y_testhat_us = clf_bb_us.predict(X_test)
y_testhat_os = clf_bb_os.predict(X_test)

# %%
# Evaluation - Undersampling
print(confusion_matrix(y_test, y_testhat_us))
# Out:
# [[7806 1598]
#  [ 435 1997]]

# %%
print(classification_report(y_test, y_testhat_us))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.83      0.88      9404
#            1       0.56      0.82      0.66      2432
#
#     accuracy                           0.83     11836
#    macro avg       0.75      0.83      0.77     11836
# weighted avg       0.87      0.83      0.84     11836

# %%
# Evaluation - Oversampling
print(confusion_matrix(y_test, y_testhat_os))
# Out:
# [[7545 1859]
#  [ 781 1651]]

# %%
print(classification_report(y_test, y_testhat_os))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.80      0.85      9404
#            1       0.47      0.68      0.56      2432
#
#     accuracy                           0.78     11836
#    macro avg       0.69      0.74      0.70     11836
# weighted avg       0.82      0.78      0.79     11836

# %% [markdown]
# ## Conclusion
# If focus on recall score of class 1 (dislike), the MultinomialMB is the best model, with recall score of class 1 = 78%, recall score of class 0 = 90% and Macro F1-score = 82% (precision of class 1 = 66%, precision of class 0 = 94%)

# %% [markdown]
# # Step 6: DEPLOYMENT & FEEDBACK/ACT

# %% [markdown]
# * Create a pipeline that helps end-user can use models easily.

# %% [markdown]
# ## Build Pipeline

# %% [markdown]
# ### Create def

# %%
def data_cleaning(data):
    df = data.copy()

    # remove unnamed columns
    df = df.loc[:, ~df.columns.str.contains('^Unnamed')]

    # feature "review_text"
    df_clean = df
    document = df_clean['review_text']

    # load edited emojicon
    file = open('lib/files/emojicon.txt', 'r', encoding="utf8")
    emoji_lst = file.read().split('\n')
    file.close()

    emoji_dict = {}
    lst_key = []
    lst_value = []
    for line in emoji_lst:
      key, value = line.split('\t')
      lst_key.append(key)
      lst_value.append(value)
      emoji_dict[key] = str(value)

    # load chosen words
    file = open('lib/files/chosen_words_full.txt', 'r', encoding="utf8")
    lst_chosen_words = file.read().split('\n')
    file.close()

    lst_spec_symbol = ['~','`','!','@','#','$','%','^','&','*','(',')','-','=','+',   '[','{','}','}','\\','|',';',':','"',     ',','<','.','>','/','?']
    lst_find_words = ['không ','ko ','kg ','chẳng ','chả ']
    lst_replace_words = ['không_','ko_','kg_','chẳng_','chả_']

    lst_document = []
    for doc in document:
      doc = doc.lower()

    # TEXT CLEANING
    # replace emojicons
      for i in range(len(lst_key)):
        doc = doc.replace(lst_key[i], ' '+lst_value[i])
      for j in doc:
        if j in emoji.UNICODE_EMOJI['en']: 
          doc = doc.replace(j, '')

    # word tokenize: sạch sẽ => sạch_sẽ
      doc = word_tokenize(doc, format='text')

    # remove special symbols
      rx = '[' + re.escape(''.join(lst_spec_symbol)) + ']' 
      doc = re.sub(rx, '', doc)

      doc = doc.replace('  ',' ')
      doc = doc.replace(' _',' ')
      doc = doc.replace('_ ',' ')

    # replace 'không ' to 'không_' co link words, v.v...
      for i in range(len(lst_find_words)):
        doc = doc.replace(lst_find_words[i], lst_replace_words[i]) 

    # remove stop_words
      lst_words = []
      for j in doc.split(' '):
        if j in lst_chosen_words: lst_words.append(j)
      doc = ' '.join(lst_words)  

      lst_document.append(doc)

    df_clean['review_text_clean'] = lst_document
    df_clean = df_clean.dropna()

    # create "review_score_new"
    df_clean['review_score_new'] = 1
    df_clean.loc[df_clean['review_score'] >= 6.8, 'review_score_new'] = 0
    df_clean['review_score_new'] = df_clean['review_score_new'].astype('int32')

    return df_clean

# %% [markdown]
# ### Create fit_transform function

# %%
from sklearn.base import BaseEstimator, TransformerMixin
class Pre_Processing(BaseEstimator, TransformerMixin):
    def __init__(self):
        print('Khởi tạo đối tượng Pre-Processing')
    def fit(self, X, y=None):
        return self
    def transform(self, data, y=None):
        import pickle

        # load encoder model
        cv = pickle.load(open('outputs/CountVectorizer_self_model.sav','rb'))

        # data cleaning
        df = data.copy()
        df_clean = data_cleaning(df)

        # apply CountVectorizer
        cv_transformed = cv.transform(df_clean['review_text_clean'].dropna())
        cv_transformed = cv_transformed.toarray()
        df_clean_cv = pd.DataFrame(cv_transformed, columns=cv.get_feature_names())
        df_clean_cv = pd.concat([df_clean.reset_index(), df_clean_cv], axis=1)
      
        return df_clean_cv

# %%
from sklearn.base import BaseEstimator, TransformerMixin
class Create_XY(BaseEstimator, TransformerMixin):
    def __init__(self):
        print('Khởi tạo đối tượng Create_XY')
    def fit(self, X, y=None):
        return self
    def transform(self, data, y=None):
        import pickle
        
        df_clean_cv = data

        # create X, y   
        X = df_clean_cv.iloc[:,6:]
        y = df_clean_cv['review_score_new']

        return X, y

# %%
# model_pre_processing = Pipeline(steps=[
#     ('Pre_Processing', Pre_Processing()),
#     ])

model_pre_processing = Pipeline(steps=[
    ('Pre_Processing', Pre_Processing()),
    ('Create_XY', Create_XY()),
    ])

model_mb = model_mb
# Out:
# Khởi tạo đối tượng Pre-Processing
# Khởi tạo đối tượng Create_XY

# %% [markdown]
# ## Save model

# %%
# model_mb = pickle.load(open('outputs/MultinomialNB_us_self_model.sav', 'rb'))

# %%
# save model
pickle.dump(model_pre_processing, open('outputs/Project2_model_pre_processing.sav', 'wb'))
pickle.dump(model_mb, open('outputs/Project2_mb_model_prediction.sav', 'wb'))

# %% [markdown]
# ## Test model

# %%
data = pd.read_csv('data_Foody.csv')
model_pre = pickle.load(open('outputs/Project2_model_pre_processing.sav', 'rb'))
model_predict = pickle.load(open('outputs/Project2_mb_model_prediction.sav', 'rb'))

# %%
X_new, y_new = model_pre.transform(data)

# %%
yhat = model_predict.predict(X_new)

# %%
print(confusion_matrix(y_new, yhat))
# Out:
# [[28301  3196]
#  [ 1927  6501]]

# %%
print(classification_report(y_new, yhat))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.90      0.92     31497
#            1       0.67      0.77      0.72      8428
#
#     accuracy                           0.87     39925
#    macro avg       0.80      0.83      0.82     39925
# weighted avg       0.88      0.87      0.87     39925

# %% [markdown]
# Conclusion:
# * When having pipeline, end-user just do 1 little steps to make prediction.
